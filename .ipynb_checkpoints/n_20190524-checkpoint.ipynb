# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.signal import find_peaks_cwt, peak_prominences

from utils.kde import smooth
wl = [i for i in range(660, 921)]
# %matplotlib inline
# Out:
# /Users/tushicheng/toast_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /Users/tushicheng/toast_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %% [markdown]
# ### 觀察穩定(30sec)

# %%
data = np.loadtxt("data/raw/20190524/IJV/live/live_1_1.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190524/IJV/calib_wl.csv", delimiter=",")

# %%
data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp

# %%
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (1191, 261)

# %% [markdown]
# ### 確認各波長隨時間改變趨勢一樣

# %%
plt.figure(figsize=(12, 6))
for i in range(740, 811, 10):
    plt.plot(data[:, i-660], label="{} nm".format(i))
plt.xlabel("time [sec]")
plt.ylabel("reflectance [gray scale]")
plt.grid()
plt.legend()
plt.xticks([i for i in range(0, 1201, 200)], labels=[str(int(i/20)) for i in range(0, 1201, 100)])
plt.show()

# %% [markdown]
# ### 確認一樣後，直接計算平均

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1), label="average from 660 to 920nm")
plt.xlabel("time [sec]")
plt.ylabel("reflectance [gray scale]")
plt.grid()
plt.legend()
plt.xticks([i for i in range(0, 1201, 200)], labels=[str(int(i/20)) for i in range(0, 1201, 100)])
plt.show()

# %% [markdown]
# # 過度換氣

# %%
data = np.loadtxt("data/raw/20190524/IJV/live/live_2_1.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190524/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (15220, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 10200]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 16000, 1200)], labels=[str(int(i/1200)) for i in range(0, 16000, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 10200
total_time = 16000

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.plot(data[300:330].mean(1))
# Out:
# Text(0.5, 1.0, 'before')

# %%
i = 310
j = 319
plt.plot(data[300:330].mean(1))
plt.scatter(i-300, data[300:330].mean(1)[i-300])
plt.scatter(j-300, data[300:330].mean(1)[j-300])

plt.title("baseline")
plt.show()

i = 9610
j = 9630
plt.plot(data[9600:9650].mean(1))
plt.scatter(i-9600, data[9600:9650].mean(1)[i-9600])
plt.scatter(j-9600, data[9600:9650].mean(1)[j-9600])

plt.title("hypoventilation")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(wl, data[310, :] - data[319, :], color="xkcd:silver")
plt.plot(wl, smooth(data[310, :], 3) - smooth(data[319, :], 3), color="xkcd:teal", label="baseline")

plt.plot(wl, data[9610, :] - data[9630, :], color="xkcd:silver")
plt.plot(wl, smooth(data[9610, :], 3) - smooth(data[9630, :], 3), color="xkcd:lightblue", label="hyperventilation")

plt.grid()
plt.legend()
plt.xticks([i for i in range(660, 921, 10)])
plt.xlabel("wavelength [nm]")
plt.ylabel("difference [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
hyp = smooth(data[9610, :], 3) - smooth(data[9630, :], 3)
base = smooth(data[310, :], 3) - smooth(data[319, :], 3)

plt.plot(wl, hyp-base)

plt.grid()
plt.legend()
plt.xlabel("wavelength [nm]")
plt.ylabel("difference [gray scale]")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(data[330:360].mean(1))

# %%
i = 342
j = 357
plt.plot(data[330:360].mean(1))
plt.scatter(i-330, data[330:360].mean(1)[i-330])
plt.scatter(j-330, data[330:360].mean(1)[j-330])

plt.title("baseline")
plt.show()

i = 9690
j = 9702
plt.plot(data[9670:9720].mean(1))
plt.scatter(i-9670, data[9670:9720].mean(1)[i-9670])
plt.scatter(j-9670, data[9670:9720].mean(1)[j-9670])

plt.title("hypoventilation")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(wl, data[342, :] - data[357, :], color="xkcd:silver")
plt.plot(wl, smooth(data[342, :], 3) - smooth(data[357, :], 3), color="xkcd:teal", label="baseline")

plt.plot(wl, data[9690, :] - data[9702, :], color="xkcd:silver")
plt.plot(wl, smooth(data[9690, :], 3) - smooth(data[9702, :], 3), color="xkcd:lightblue", label="hyperventilation")

plt.grid()
plt.legend()
plt.xticks([i for i in range(660, 921, 10)])
plt.xlabel("wavelength [nm]")
plt.ylabel("difference [gray scale]")
plt.show()

# %%
plt.plot(data[9720:9750].mean(1))

# %%
i = 378
j = 391
plt.plot(data[370:400].mean(1))
plt.scatter(i-370, data[370:400].mean(1)[i-370])
plt.scatter(j-370, data[370:400].mean(1)[j-370])

plt.title("baseline")
plt.show()

i = 9724
j = 9735
plt.plot(data[9720:9750].mean(1))
plt.scatter(i-9720, data[9720:9750].mean(1)[i-9720])
plt.scatter(j-9720, data[9720:9750].mean(1)[j-9720])

plt.title("hypoventilation")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(wl, data[378, :] - data[391, :], color="xkcd:silver")
plt.plot(wl, smooth(data[378, :], 3) - smooth(data[391, :], 3), color="xkcd:teal", label="baseline")

plt.plot(wl, data[9724, :] - data[9735, :], color="xkcd:silver")
plt.plot(wl, smooth(data[9724, :], 3) - smooth(data[9735, :], 3), color="xkcd:lightblue", label="hyperventilation")

plt.grid()
plt.legend()
plt.xticks([i for i in range(660, 921, 10)])
plt.xlabel("wavelength [nm]")
plt.ylabel("difference [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190524/IJV/live/live_2_2.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190524/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (12987, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 9000]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 13600, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 13600, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 9000
total_time = 13600

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190524/IJV/live/live_2_3.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190524/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (13828, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 10200]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 13600, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 13600, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 10200
total_time = 13600

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %% [markdown]
# # 吸氧氣

# %%
data = np.loadtxt("data/raw/20190524/IJV/live/live_3_1.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190524/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (4882, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 1800]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 4801, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 4801, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 1800
total_time = 4801

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190524/IJV/live/live_3_2.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190524/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (6681, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 1800]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 7201, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 7201, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 1800
total_time = 4801

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190524/IJV/live/live_3_3.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190524/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (5666, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 1800]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 6000, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 6000, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 1800
total_time = 4801

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()
