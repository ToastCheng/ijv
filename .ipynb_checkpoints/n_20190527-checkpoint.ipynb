# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

from utils.kde import smooth
wl = [i for i in range(660, 921)]
# %matplotlib inline

# %% [markdown]
# ### 觀察穩定(30sec)

# %%
data = np.loadtxt("data/raw/20190527/IJV/live/live_1_1.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190527/IJV/calib_wl.csv", delimiter=",")

# %%
data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp

# %%
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (3598, 261)

# %% [markdown]
# ### 確認各波長隨時間改變趨勢一樣

# %%
plt.figure(figsize=(12, 6))
for i in range(740, 811, 10):
    plt.plot(data[:1200, i-660], label="{} nm".format(i))
plt.xlabel("time [sec]")
plt.ylabel("reflectance [gray scale]")
plt.grid()
plt.legend()
plt.xticks([i for i in range(0, 1201, 200)], labels=[str(int(i/20)) for i in range(0, 1201, 100)])
plt.show()

# %% [markdown]
# ### 確認一樣後，直接計算平均

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1)[:1200], label="average from 660 to 920nm")
plt.xlabel("time [sec]")
plt.ylabel("reflectance [gray scale]")
plt.grid()
plt.legend()
plt.xticks([i for i in range(0, 1201, 200)], labels=[str(int(i/20)) for i in range(0, 1201, 100)])
plt.show()

# %% [markdown]
# # 過度換氣

# %%
data = np.loadtxt("data/raw/20190527/IJV/live/live_2_1.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190527/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (15032, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 10200]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 16000, 1200)], labels=[str(int(i/1200)) for i in range(0, 16000, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 10200
total_time = 16000

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[:, wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190527/IJV/live/live_2_2.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190527/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (15162, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 9000]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 13600, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 13600, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 10200
total_time = 16000

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[:, wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %% [markdown]
# # 吸氧氣

# %%
data = np.loadtxt("data/raw/20190527/IJV/live/live_3_1.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190527/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (6180, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 2400]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 4801, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 4801, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 2400
total_time = 6200

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[:, wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190527/IJV/live/live_3_2.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190527/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (7941, 261)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 1800]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, 7201, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, 7201, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 2400
total_time = 7900

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[:, wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190527/IJV/live/live_4_1.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190527/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (11062, 261)

# %%
plt.figure(figsize=(12, 6))
s_time = 600
e_time = 7200
total_time = 11000

plt.plot(data.mean(1))
for text, time in zip(["start", "end"], [600, 7200]):
    plt.plot(
        [time, time], 
        [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

plt.xticks([i for i in range(0, total_time, 1200)], 
           labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 7200
total_time = 11000

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[:, wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
data = np.loadtxt("data/raw/20190527/IJV/live/live_4_2.csv", delimiter=",")
calib_wl = np.loadtxt("data/raw/20190527/IJV/calib_wl.csv", delimiter=",")

data_interp = []
for i in range(data.shape[0]):
     data_interp += [np.interp(wl, calib_wl, data[i, :])]
data_interp = np.asarray(data_interp)
data = data_interp
print("檔案格式(秒, 波長數): ", data.shape)
# Out:
# 檔案格式(秒, 波長數):  (12726, 261)

# %%
from PyEMD import EMD
base =660
data850 = data[:, 850-base]
data800 = data[:, 800-base]
data760 = data[:, 760-base]

imf = EMD().emd(data800, np.arange(len(data800)))

# %%
arti = imf[-1]/imf[-1].mean()

plt.figure(figsize=(12, 6))
plt.plot(data760 / arti)
plt.plot(data800 / arti)
plt.plot(data850 / arti)

# %%
arti = imf[-1] - imf[-1].mean()

plt.figure(figsize=(12, 6))

plt.plot((data760 - arti)[200:-200], color="gray", alpha=0.2)
plt.plot((data800 - arti)[200:-200], color="gray", alpha=0.2)
plt.plot((data850 - arti)[200:-200], color="gray", alpha=0.2)

plt.plot(smooth(data760 -arti, 200)[200:-200], label="760 nm")
plt.plot(smooth(data800 -arti, 200)[200:-200], label="800 nm")
plt.plot(smooth(data850 -arti, 200)[200:-200], label="850 nm")


for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[:, wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()

# %%
# plt.figure(figsize=(12, 6))
# s_time = 600
# e_time = 7800
# total_time = 13000

# plt.plot(data.mean(1))
# for text, time in zip(["start", "end"], [s_time, e_time]):
#     plt.plot(
#         [time, time], 
#         [data.mean(1).min()*0.99, data.mean(1).max()*1.01], 
#         color="C0",
#         linestyle=":",
#         linewidth=2
#     )

#     plt.text(time+90, data.mean(1).max()*1.01, text, fontsize=12)

# plt.xticks([i for i in range(0, total_time, 1200)], 
#            labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
# plt.grid()

# plt.xlabel("time [min]")
# plt.ylabel("reflectance [gray scale]")
# plt.show()

# %%
plt.figure(figsize=(12, 6))
base = 660
s_time = 600
e_time = 7800
total_time = 13000

wl_select = [760, 800, 850]
wl_select = [i-base for i in wl_select]
for i in wl_select:
    plt.plot(data[:, i], label="{} nm".format(i+base))
    
    
for text, time in zip(["start", "end"], [s_time, e_time]):
    plt.plot(
        [time, time], 
        [data[:, wl_select].min()*0.99, data[:, wl_select].max()*1.01], 
        color="C0",
        linestyle=":",
        linewidth=2
    )

    plt.text(time+90, data[:, wl_select].max()*1.01, text, fontsize=12)

    
plt.xticks([i for i in range(0, total_time, 1200)], labels=[str(int(i/1200)) for i in range(0, total_time, 1200)])
plt.grid()
plt.legend()

plt.xlabel("time [min]")
plt.ylabel("reflectance [gray scale]")
plt.show()
