# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    epoch  spec_rmsp  absorb_rmsp       s_b       s_s       s_w       s_f  \
# 0    0.0   6.113638          0.0  0.035946  0.744445  0.648154  0.440864
# 1    1.0   6.139427          0.0  0.035946  0.744445  0.648154  0.440864
# 2    2.0   6.172493          0.0  0.034803  0.734562  0.657639  0.434558
# 3    3.0   6.175485          0.0  0.035893  0.735728  0.660682  0.444571
# 4    4.0   6.192120          0.0  0.035971  0.742570  0.673430  0.435817
#
#         s_m    s_muspx    s_bmie  ...       m_w       m_c    m_muspx  \
# 0  0.006748  29.490392  1.856837  ...  0.147886  0.757329  12.018075
# 1  0.006748  29.490392  1.856837  ...  0.140818  0.757329  12.018075
# 2  0.006703  30.271738  1.871076  ...  0.137106  0.748122  12.048647
# 3  0.006726  30.610176  1.862632  ...  0.144085  0.731690  12.007798
# 4  0.006698  30.735987  1.863796  ...  0.134940  0.749436  12.077944
#
#      m_bmie       i_s   i_muspx  i_bmie       c_s   c_muspx  c_bmie
# ...

# %% [markdown]
# ## 20190524

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 6):
    df = pd.read_csv("fitting/20190524_split/1_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
ax.grid()
ax.set_ylim(0, 1)
ax.legend([str(i) for i in range(1, 6)])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7227467027549251
# 0.7116816396571402
# 0.7314529095733864
# 0.7298922807992815
# 0.7616648396697631

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 6):
    df = pd.read_csv("fitting/20190524_split/1_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["s_s"].plot(ax=ax)
ax.grid()
ax.set_ylim(0, 1)
ax.legend([str(i) for i in range(1, 6)])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7227467027549251
# 0.7116816396571402
# 0.7314529095733864
# 0.7298922807992815
# 0.7616648396697631

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/2_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
    print("std:", df["i_s"].iloc[:50].std())
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.6607485406253428
# std: 0.00644020803398852
# 0.5217050449863782
# std: 0.002279981290912052
# 0.7902772227975691
# std: 0.003543844805552421

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/2_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["s_s"].plot(ax=ax)
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.6607485406253428
# 0.5217050449863782
# 0.7902772227975691

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/3_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)    
    print("std:", df["i_s"].iloc[:50].std())
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7221294019854845
# std: 0.002676830891199377
# 0.4869581049917355
# std: 0.0006767997842243906
# 0.7191056428896728
# std: 0.005525891021700281

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/3_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["s_s"].plot(ax=ax)
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7221294019854845
# 0.4869581049917355
# 0.7191056428896728

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/4_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
    print("std:", df["i_s"].iloc[:50].std())
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7154769625271749
# std: 0.001921352670903707
# 0.5300303085762598
# std: 0.0059755161888977275
# 0.777164337101465
# std: 0.01414441603685278

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/4_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["s_s"].plot(ax=ax)
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7154769625271749
# 0.5300303085762598
# 0.777164337101465

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/5_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
    print("std:", df["i_s"].iloc[:50].std()/df["i_s"].iloc[:50].mean())
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "inhale", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7958678454955505
# std: 0.007697060443511818
# 0.7118169721958075
# std: 0.05583653919138026
# 0.7026260792579548
# std: 0.0047417417019184355

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/5_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["s_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "inhale", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7958678454955505
# std: 0.007697060443511818
# 0.7118169721958075
# std: 0.05583653919138026
# 0.7026260792579548
# std: 0.0047417417019184355

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/6_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
    print("cv: ", df["i_s"].iloc[:50].std()/df["i_s"].iloc[:50].mean())
    print("std:", df["i_s"].iloc[:50].std()/df["i_s"].iloc[:50].mean())

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "inhale", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7472926005499996
# cv:  0.015231826795153563
# std: 0.015231826795153563
# 0.7270872203650185
# cv:  0.009579487066437107
# std: 0.009579487066437107
# 0.6237191365176341
# cv:  0.01845901559737967
# std: 0.01845901559737967

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190524_split/7_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
    print("cv: ", df["i_s"].iloc[:50].std()/df["i_s"].iloc[:50].mean())
    print("std:", df["i_s"].iloc[:50].std())

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "inhale", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7300507587853994
# cv:  0.0052072241518715525
# std: 0.0038207738908240915
# 0.8363257238133459
# cv:  0.005503973242617693
# std: 0.004600282554168103
# 0.7170136700212614
# cv:  0.026612074650012214
# std: 0.019461014390095968

# %% [markdown]
# ## 20190527

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 2):
    df = pd.read_csv("fitting/20190527_split/1_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
ax.grid()
ax.set_ylim(0, 1)
ax.legend([str(i) for i in range(1, 6)])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7587936088498557

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190527_split/2_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[1])
    df[::-1].reset_index()["i_s"].plot(ax=ax)
ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7068609499045178
# 0.6061729244584065
# 0.6960754838240151

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190527_split/3_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hyperventilation", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7379087893591219
# 0.6348726501750519
# 0.7863522342147562

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190527_split/4_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "inhale", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7652690763807585
# 0.7458025297692128
# 0.7655242690169266

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190527_split/5_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "inhale", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7339710142688503
# 0.7803245929336969
# 0.7098226172450123

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190527_split/6_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "suspend breathe", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7884449728954064
# 0.6957337198077702
# 0.7716708451890991

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190527_split/7_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "suspend breathe", "rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7366280253096774
# 0.45235718660028207
# 0.7026736656010177

# %% [markdown]
# ## 20190528

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 2):
    df = pd.read_csv("fitting/20190528_split/1_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend([str(i) for i in range(1, 6)])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7229798539196998

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 6):
    df = pd.read_csv("fitting/20190528_split/2_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline"] + ["hyperventilation 1", "rest 1"] + ["hyperventilation 2", "rest 2"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7274669853402569
# 0.6391365179852707
# 0.7132873817668461
# 0.4326181344190516
# 0.7546536037054516

# %%
for i in range(1, 6):
    df = pd.read_csv("fitting/20190528_split/2_"+str(i)+"/log/log.csv")
    print(np.std(df["i_s"].iloc[:50])*4)
# Out:
# 0.055575086302850955
# 0.09395257496915659
# 0.026797119475800834
# 0.018037188896362518
# 0.03253053880565203

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 6):
    df = pd.read_csv("fitting/20190528_split/3_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline"] + ["hyperventilation 1", "rest 1"] + ["hyperventilation 2", "rest 2"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7522544513898755
# 0.5004856102746863
# 0.7301642667710992
# 0.5243477887681756
# 0.7376799228204622

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190528_split/4_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "inhale","rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7225766242233288
# 0.76377281026099
# 0.7239888121489235

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
for i in range(1, 4):
    df = pd.read_csv("fitting/20190528_split/5_{}/log/log.csv".format(i))
    print(df["i_s"].iloc[0])
    df[::-1].reset_index()["i_s"].plot(ax=ax)

ax.grid()
ax.set_ylim(0, 1)
ax.legend(["baseline", "hold","rest"])
ax.set_xlabel("gene index [-]")
ax.set_ylabel("ScvO2 [-]")
plt.show()
# Out:
# 0.7349060437197847
# 0.5689404759560586
# 0.7350421693857322
