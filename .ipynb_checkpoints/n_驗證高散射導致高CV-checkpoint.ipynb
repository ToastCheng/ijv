# %%
from utils import load_mch
from utils import load_mc2
import matplotlib.pyplot as plt

# %%
df, _, _ = load_mch("output/quicktest/mcx_output/quicktest_700.mch")

# %%
df.head(1)
# Out:
#    detector_idx  scattering    media_0   media_1   media_2    media_3  \
# 0           2.0       913.0  11.647377  5.151907  51.43782  23.728918
#
#    media_4           x          y         z        dx        dy        dz  \
# 0      0.0  104.212715  76.799797 -0.000061  0.687294 -0.183059 -0.702934
#
#    weight
# 0     1.0

# %%
df.to_csv("output/quicktest/mcx_output/quicktest_700.csv")

# %%
df.iloc[:, 2:4].values
# Out:
# array([[11.64737701,  5.15190744],
#        [11.20310307,  8.45282078],
#        [10.72029877,  4.98828602],
#        ...,
#        [19.70126343, 32.84867859],
#        [17.56652832, 19.27127266],
#        [16.98185158, 32.71096039]])

# %%
df[["media_0", "media_1"]].values
# Out:
# array([[11.64737701,  5.15190744],
#        [11.20310307,  8.45282078],
#        [10.72029877,  4.98828602],
#        ...,
#        [19.70126343, 32.84867859],
#        [17.56652832, 19.27127266],
#        [16.98185158, 32.71096039]])

# %%
d1, h1, _= load_mch("output/quicktest_path/mcx_output/quicktest_path_700.mch")
d1.mean(), h1
# Out:
# (detector_idx      1.742956
#  scattering      407.277556
#  media_0          12.459677
#  media_1          10.702085
#  media_2          81.539562
#  media_3          25.965748
#  media_4           6.410315
#  x               101.760547
#  y                74.971765
#  z                -0.000061
#  dx                0.016047
#  dy               -0.000443
#  dz               -0.690731
#  weight            0.002523
#  dtype: float64,
#  {'version': 1,
#   'maxmedia': 5,
#   'detnum': 3,
#   'colcount': 14,
#   'total_photon': 20000000,
#   'detected': 9263,
#   'saved_photon': 9263,
#   'unitmm': 0.25,
#   'seed_byte': 16,
#   'normalize': 160.0,
#   'respin': 1})

# %%
d2, h2, _= load_mch("output/quicktest_path/mcx_output/quicktest_path_700.mch")
d2.mean(), h2
# Out:
# (detector_idx      1.000000
#  scattering      371.767615
#  media_0          12.261619
#  media_1          10.676516
#  media_2          72.893305
#  media_3          21.519433
#  media_4           5.295181
#  x                89.767156
#  y                75.012840
#  z                -0.000061
#  dx                0.016075
#  dy               -0.004229
#  dz               -0.689314
#  weight            0.004529
#  dtype: float64,
#  {'version': 1,
#   'maxmedia': 5,
#   'detnum': 3,
#   'colcount': 14,
#   'total_photon': 4428,
#   'detected': 4428,
#   'saved_photon': 4428,
#   'unitmm': 0.25,
#   'seed_byte': 16,
#   'normalize': 0.000609181763138622,
#   'respin': 1})

# %%
ddd[ddd.detector_idx==1].shape
# Out:
# (4462, 14)

# %%
_.shape
# Out:
# (9048, 16)

# %%
d = load_mc2("output/quicktest_path/mcx_output/quicktest_path_700.mc2", (150, 150, 200))

plt.imshow(d[75, :, :100].T)
plt.colorbar()
plt.show()
plt.imshow(d[:, 75, :100].T)
plt.colorbar()
plt.show()

# %% [markdown]
# {
#     "mua": 0.07,
#     "g": 0.71,
#     "name": "skin",
#     "n": 1.4,
#     "mus": 5
# },
# {
#     "mua": 0.05,
#     "g": 0.9,
#     "name": "fat",
#     "n": 1.4,
#     "mus": 5
# },
# {
#     "mua": 0.1,
#     "g": 0.9,
#     "name": "muscle",
#     "n": 1.4,
#     "mus": 3
# },
# {
#     "mua": 50,
#     "g": 0.9,
#     "name": "IJV",
#     "n": 1.4,
#     "mus": 1
# },
# {
#     "mua": 30,
#     "g": 0.94,
#     "name": "CCA",
#     "n": 1.4,
#     "mus": 13.6
# }

# %%
dr = load_mc2("output/quicktest_path/mcx_output/quicktest_path_700.mc2", (150, 150, 200))

# plt.imshow(dr[75, :, :100].T)
# plt.colorbar()
# plt.show()
plt.imshow(dr[:, 75, :100].T)
plt.colorbar()
plt.show()

# %%
dr = load_mc2("output/quicktest_path_high_mus/mcx_output/quicktest_path_high_mus_700.mc2", (150, 150, 200))

plt.imshow(dr[75, :, :100].T)
plt.colorbar()
plt.show()
plt.imshow(dr[:, 75, :100].T)
plt.colorbar()
plt.show()
