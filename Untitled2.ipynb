# %%
import pandas as pd
import numpy as np 
from glob import glob
import matplotlib.pyplot as plt

from utils.kde import smooth
from utils.calibration import Calibrator

# %matplotlib inline

# %%
df = pd.read_excel("20190118_IJV-修改.xlsx")
df.head()
# Out:
#    Wavelength (nm)        PC        PH         PI         PK  chenyi_lie2  \
# 0         539.5939  0.000000  1.666667  11.000000  33.666667     1.230186
# 1         539.9378  7.333333  9.000000  11.333333  34.333333     6.904762
# 2         540.2817  9.000000  4.666667  13.000000  36.333333     7.849206
# 3         540.6256  7.333333  6.000000  16.666667  31.333333     7.658841
# 4         540.9695  1.333333  4.000000  14.000000  36.000000     6.444444
#
#    chenyi_lie15_1
# 0        1.455813
# 1        7.013605
# 2        7.374150
# 3        7.585131
# 4        5.551020

# %%
phantom = df.iloc[:, 0:5]
live = df.iloc[:, 5:]


bw = 7

live["cy1"] = smooth(live["chenyi_lie15_1"], band_width=bw)
live["cy2"] = smooth(live["chenyi_lie2"], band_width=bw)
live = live[["cy1", "cy2"]]

phantom["PC"] = smooth(phantom["PC"], band_width=bw)
phantom["PH"] = smooth(phantom["PH"], band_width=bw)
phantom["PI"] = smooth(phantom["PI"], band_width=bw)
phantom["PK"] = smooth(phantom["PK"], band_width=bw)
# Out:
# /home/toast/toast/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/toast/toast/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/toast/toast/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/toast/toast/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/toast/toast/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/toast/toast/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.plot(phantom["Wavelength (nm)"], live["cy1"], label="cy1")
plt.plot(phantom["Wavelength (nm)"], live["cy2"], label="cy2")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(phantom["Wavelength (nm)"], phantom["PC"], label="PC")
plt.plot(phantom["Wavelength (nm)"], phantom["PH"], label="PH")
plt.plot(phantom["Wavelength (nm)"], phantom["PI"], label="PI")
plt.plot(phantom["Wavelength (nm)"], phantom["PK"], label="PK")
plt.legend()
plt.grid()
plt.show()

# %%
sim = []
for p in ["C", "H", "I", "K"]:
    path = "output/%s/result/result.pkl" % p
    sim.append(np.load(path)[p])

# %%
sim[0] = np.asarray(sim[0])
sim[1] = np.asarray(sim[1])
sim[2] = np.asarray(sim[2])
sim[3] = np.asarray(sim[3])

# %%
bw = 0.8
sim[0] = smooth(sim[0].reshape(-1), band_width=bw)
sim[1] = smooth(sim[1].reshape(-1), band_width=bw)
sim[2] = smooth(sim[2].reshape(-1), band_width=bw)
sim[3] = smooth(sim[3].reshape(-1), band_width=bw)

# %%
sim[0].shape
sim = pd.DataFrame({
    "wavelength": [i for i in range(650, 1001, 10)],
    "C": sim[0],
    "H": sim[1],
    "I": sim[2],
    "K": sim[3]
})

# %%
plt.plot(sim["wavelength"], sim["C"], label="SC")
plt.plot(sim["wavelength"], sim["H"], label="SH")
plt.plot(sim["wavelength"], sim["I"], label="SI")
plt.plot(sim["wavelength"], sim["K"], label="SK")
plt.legend()
plt.grid()
plt.show()

# %%
sim.head()
# Out:
#    wavelength             C             H             I             K
# 0         650  5.919727e-14  2.876197e-11  8.853596e-10  6.224517e-09
# 1         660  5.542547e-13  3.936309e-11  1.033313e-09  7.553950e-09
# 2         670  1.189016e-12  5.073700e-11  1.177454e-09  9.060267e-09
# 3         680  5.684886e-13  3.509606e-11  1.544947e-09  9.960530e-09
# 4         690  3.183018e-13  3.723888e-11  1.917485e-09  1.067770e-08

# %%
p_wl = phantom["Wavelength (nm)"].tolist()
_p_data = phantom.iloc[:, 1:].values.T

# %%
_p_data.shape
# Out:
# (4, 1600)

# %%
wl = [i for i in range(650, 1001, 10)]

# %%
p_data = []
for p in _p_data:
    p_data.append(np.interp(wl, p_wl, p))
p_data = np.asarray(p_data)

# %%
p_data.shape
# Out:
# (4, 36)

# %%
s_data = sim.iloc[:, 1:].values.T

# %%
s_data.shape
# Out:
# (4, 36)

# %%
def stand(x):
    x = (x - x.mean())/x.std()
    return x

# %%
for i in range(36):
    plt.title("wavelength: " + str(wl[i]))
    plt.scatter([1,2,3,4], stand(p_data[:, i]))
    plt.scatter([1,2,3,4], stand(s_data[:, i]))
    plt.plot([1,2,3,4], stand(p_data[:, i]), label="phantom")
    plt.plot([1,2,3,4], stand(s_data[:, i]), label="sim")
    plt.xticks([1,2,3,4], ["C", "H", "I", "K"])
    plt.legend()
    plt.grid()
    plt.show()

# %%
sim.head(3)
# Out:
#    wavelength             C             H             I             K
# 0         650  5.919727e-14  2.876197e-11  8.853596e-10  6.224517e-09
# 1         660  5.542547e-13  3.936309e-11  1.033313e-09  7.553950e-09
# 2         670  1.189016e-12  5.073700e-11  1.177454e-09  9.060267e-09

# %%
phantom.head(3)
# Out:
#    Wavelength (nm)        PC        PH        PI         PK
# 0         539.5939  2.999872  3.398104  7.890724  24.895237
# 1         539.9378  3.235912  3.668950  8.498756  27.136860
# 2         540.2817  3.444246  3.906007  9.032034  29.212350

# %%
calib = Calibrator(4, 1)

# %%
len(df["Wavelength (nm)"].tolist())
len(phantom["PK"].tolist())
# Out:
# 1600

# %%
phantom_interp = []
live_interp = []

for p in ["PC", "PH", "PI", "PK"]:
    phantom_interp.append(
        np.interp(wl, df["Wavelength (nm)"].tolist(), phantom[p].tolist())
    )
for l in ["cy1", "cy2"]:
    live_interp.append(
        np.interp(wl, df["Wavelength (nm)"], live[l])
    )

phantom_interp = np.asarray(phantom_interp)
live_interp = np.asarray(live_interp)

# %%
sim.head()
sim = sim.iloc[:, 1:].values
sim.shape
# Out:
# (36, 4)

# %%
print(phantom_interp.shape)
print(sim.shape)
a, b, rr = calib.fit(phantom_interp, sim.T)
# Out:
# (4, 36)
# (36, 4)
# COMPUTE!
# 5.0688166641447665e-21
# 2.6789049163608362e-17
# 0.00018921226480223533
# COMPUTE!
# 1.0829662613646287e-20
# 3.9524381057573997e-17
# 0.0002739995497430064
# COMPUTE!
# 3.7420715346156987e-20
# 5.700820734347414e-17
# 0.0006564092626294559
# COMPUTE!
# 2.3452212219273975e-20
# 6.830076782956646e-17
# 0.0003433667433694916
# COMPUTE!
# 6.872888818244629e-20
# 7.77948596515523e-17
# 0.0008834631039928213
# COMPUTE!
# 9.128667248494427e-20
# 1.0111907020720742e-16
# 0.0009027641600925012
# COMPUTE!
# 2.7673706125347834e-19
# 1.2415968206454482e-16
# 0.0022288802343228913
# COMPUTE!
# 4.960861384830721e-19
# 1.3158822154751032e-16
# 0.0037699889294723742
# COMPUTE!
# 4.416696015579357e-19
# 1.1293978563703216e-16
# 0.0039106644223443204
# [-8.037754957167178e-11, -1.1208369975457721e-10, -1.7378637759036888e-10, -1.4817031932496853e-10, -1.0003815712763001e-10, -1.267900930563658e-10, -5.167568493207025e-11, 1.7018532091485894e-12, -7.562007289275527e-12, 1.3492369052254652e-10, 1.8549859390750072e-10, -4.7485285484442585e-11, -1.8473742826307232e-10, 5.127042695103537e-11, 3.4317554763180685e-10, 3.610296491139237e-10, -6.874226518918097e-11, -2.1337282091715735e-10, 1.5583443549030035e-10, 3.493083027249936e-10, 3.3673051603416793e-10, 2.7392303385802376e-10, 5.636151496836939e-10, 5.569416993717775e-10, 4.813505399154086e-10, 8.97793332291965e-11, -1.905171530345143e-10, -5.121318605626514e-10, -1.1200103242941573e-09, -2.740650048250258e-09, -3.4441575190495152e-09, -1.6329682053957742e-09, -1.227217782826749e-09, -9.714394307221722e-10, -2.0819372929724607e-10, -2.399919493217536e-09]

# %%
rr
# Out:
# [0.9998107877351977,
#  0.999726000450257,
#  0.9993435907373706,
#  0.9996566332566305,
#  0.9991165368960072,
#  0.9990972358399075,
#  0.9977711197656771,
#  0.9962300110705277,
#  0.9960893355776557,
#  0.9919745725045849,
#  0.9939223100633316,
#  0.9969719728282811,
#  0.996665904786452,
#  0.99207620422395,
#  0.9850971309774333,
#  0.984353310132124,
#  0.9926825840402258,
#  0.992685376531164,
#  0.9850686864841967,
#  0.9802388551465897,
#  0.9781623498829268,
#  0.9776540379054346,
#  0.9669880192545539,
#  0.9568135029740265,
#  0.9447927637657962,
#  0.9535838045293306,
#  0.9887043000644005,
#  0.9827116445548947,
#  0.982933973213337,
#  0.9919714870582033,
#  0.9940535376407267,
#  0.9880091011902767,
#  0.9854269051111653,
#  0.9818019422220761,
#  0.9772826078568337,
#  0.9968715887577306]

# %%
np.mean(rr)
# Out:
# 0.9868427701397022

# %%
# cy1 = calib.calibrate(live_interp[0], )
# cy2 = calib.calibrate(live_interp[0], )
plt.plot(wl, a * live_interp[0]  + b, label="cy1")
plt.plot(wl, a * live_interp[1]  + b, label="cy2")
plt.legend()
plt.grid()
plt.show()

# %%
sim_large_path = "output/20190121_large/result/result.pkl"
sim_small_path = "output/20190225_small/result/result.pkl"
large = np.load(sim_large_path)
small = np.load(sim_small_path)
large.shape
# Out:
# (1, 101, 3, 36)

# %%
scv = 10
plt.plot(wl, smooth(large[0][scv][1], band_width=0.8), label="large")
plt.plot(wl, smooth(small[0][scv][1], band_width=0.8), label="small")
plt.grid()
plt.legend()
plt.show()

# %%
sim
# Out:
# array([[5.91972664e-14, 2.87619658e-11, 8.85359610e-10, 6.22451698e-09],
#        [5.54254745e-13, 3.93630861e-11, 1.03331299e-09, 7.55394954e-09],
#        [1.18901643e-12, 5.07370025e-11, 1.17745369e-09, 9.06026729e-09],
#        [5.68488590e-13, 3.50960616e-11, 1.54494678e-09, 9.96053022e-09],
#        [3.18301775e-13, 3.72388789e-11, 1.91748471e-09, 1.06776993e-08],
#        [1.13702941e-12, 5.02697762e-11, 2.25536459e-09, 1.21884161e-08],
#        [1.79242443e-12, 8.02400338e-11, 2.84940285e-09, 1.35680721e-08],
#        [8.49931885e-13, 1.26209478e-10, 3.23973599e-09, 1.40247114e-08],
#        [3.08918153e-13, 1.34549067e-10, 3.10185326e-09, 1.30116200e-08],
#        [1.21266142e-12, 2.52358613e-10, 3.38727470e-09, 1.20885194e-08],
#        [2.57562492e-12, 5.03176913e-10, 4.97087662e-09, 1.83137943e-08],
#        [3.10606004e-12, 5.45555160e-10, 6.57534923e-09, 2.68179029e-08],
#        [5.67238044e-12, 5.28017961e-10, 8.34430095e-09, 3.36920392e-08],
#        [9.94501101e-12, 5.05473445e-10, 9.77176341e-09, 3.47164926e-08],
#        [1.61088132e-11, 5.45794629e-10, 1.06447949e-08, 3.34441101e-08],
#        [1.34236741e-11, 6.52823284e-10, 1.12666981e-08, 3.45272143e-08],
#        [8.30164655e-12, 7.88464141e-10, 1.10037175e-08, 3.74613648e-08],
#        [1.56732449e-11, 7.91999156e-10, 1.22536284e-08, 4.17649026e-08],
#        [2.62354506e-11, 8.23911339e-10, 1.48493101e-08, 4.48195330e-08],
#        [2.11027414e-11, 9.10994453e-10, 1.58455359e-08, 4.47496040e-08],
#        [1.02962339e-11, 9.33565837e-10, 1.58091180e-08, 4.30115373e-08],
#        [1.68445945e-11, 9.69353318e-10, 1.69283474e-08, 4.56102019e-08],
#        [3.05166306e-11, 9.19263482e-10, 1.69325212e-08, 4.16582879e-08],
#        [2.34424067e-11, 6.97549656e-10, 1.32770842e-08, 3.01006895e-08],
#        [2.29842114e-11, 4.71634527e-10, 9.59383364e-09, 2.02093990e-08],
#        [1.11176933e-11, 1.77345327e-10, 4.14798875e-09, 8.48746473e-09],
#        [7.30406687e-12, 1.27106265e-10, 2.87808296e-09, 7.15954855e-09],
#        [2.54971199e-11, 6.07890395e-10, 1.19856846e-08, 3.13957824e-08],
#        [6.20229935e-11, 1.64900461e-09, 2.71822447e-08, 7.42784651e-08],
#        [9.75938137e-11, 2.68291479e-09, 3.30543749e-08, 1.01720737e-07],
#        [1.13518914e-10, 3.87511918e-09, 3.78927185e-08, 1.19643723e-07],
#        [1.60902856e-10, 5.53226701e-09, 4.42906215e-08, 1.22683150e-07],
#        [2.49807825e-10, 6.34741257e-09, 4.77297766e-08, 1.27122690e-07],
#        [3.21364219e-10, 6.45772316e-09, 4.96911538e-08, 1.27295264e-07],
#        [2.56638390e-10, 6.27217375e-09, 4.44233558e-08, 1.05843351e-07],
#        [1.33332081e-10, 4.37405419e-09, 2.46126434e-08, 7.39120230e-08]])

# %%
pp_data = stand(p_data)
ss_data = stand(s_data)
pp_data = p_data
ss_data = s_data

x = np.arange(-0.8, 1.5, 0.05)
x = np.arange(0, 20000, 100)
for i in range(36):
    plt.title("wavelength" + str(wl[i]))
    for j in range(4):
        
        plt.scatter(pp_data[j, i], ss_data[j, i])
    plt.plot(x, a[i]* x + b[i])
#     plt.legend()
    plt.ylim([-5e-9, 1e-7])
    plt.grid()
    plt.show()
