# %%
from scipy.signal import find_peaks_cwt, find_peaks, peak_prominences
import numpy as np 
import matplotlib.pyplot as plt

# %%
l = np.loadtxt("data/raw/20190524_split/IJV/live/live_1_1.csv", delimiter=",")

# %%
l = l[:100, 1]
plt.plot(l)

# %%
# p = find_peaks_cwt(l, np.arange(3, 5))
p, _ = find_peaks(l)
p
# Out:
# array([ 1,  8, 10, 13, 16, 23, 28, 30, 33, 36, 42, 44, 48, 51, 54, 59, 61,
#        65, 68, 72, 75, 78, 80, 83, 87, 91, 95, 98])

# %%
plt.plot(l)
plt.scatter(p, l[p])

# %%
filter = peak_prominences(l, p)[0] > 10

# %%
filter
# Out:
# array([False, False, False, False,  True, False, False, False,  True,
#        False, False, False, False, False,  True, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
p[filter]
# Out:
# array([16, 33, 54, 65])
