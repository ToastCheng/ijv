# %%
from utils.mch import MCHHandler
from utils import load_mch
import numpy as np

# %%
df, header, _ = load_mch("train/mch/WeBCSN7uUA.mch", compress_ratio=5) #, _total_photon=5e10)

# %%
df
# Out:
#           detector_idx    media_0    media_1     media_2     media_3  \
# 0                  2.0   4.171691   1.550825   13.086718   67.709084
# 1                  1.0  15.398694   1.734105   12.358774   33.242973
# 2                  1.0  13.065117   4.656448   13.795454   20.447393
# 3                  1.0   9.063988   1.955161    9.261777   39.192726
# 4                  2.0   6.660291   1.750435   11.955441   88.717461
# 5                  3.0  15.881066   3.277208    4.322872   57.736332
# 6                  1.0  12.229302   6.293495   21.736902   34.271198
# 7                  1.0   7.407924   5.131553   23.009659   36.022808
# 8                  1.0   9.721776   3.785836   12.642691   83.478218
# 9                  1.0  14.191994   3.299253   21.643164   57.382786
# 10                 1.0   5.336582   2.038034    3.278048   25.766018
# 11                 1.0  14.078749   2.980127   30.543791   82.266098
# 12                 1.0   6.645542   1.739954   21.388609   16.276779
# ...
