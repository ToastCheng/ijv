# %%
import numpy as np
import pandas as pd 

from glob import glob
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
# !ls data/calibrated/20190502
# Out:
# 20190502_1_1.csv 20190502_1_2.csv

# %%
spec_list = glob("data/calibrated/20190502/*")
spec = []
for sl in spec_list:
    print(sl)
    spec.append(pd.read_csv(sl))
# Out:
# data/calibrated/20190502/20190502_1_1.csv
# data/calibrated/20190502/20190502_1_2.csv

# %%
wl = [i for i in range(650, 1001, 10)]

# %%
plt.plot(wl, spec[0]["max"], label="max")
plt.plot(wl, spec[0]["min"], label="min")
plt.legend()
plt.grid()
