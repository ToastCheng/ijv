# %%
from engine import Engine
from glob import glob 
import os
from random import uniform
from copy import deepcopy

from utils.ga import GA
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
def rmse(x, y):

    x, y = np.array(x), np.array(y)
    return 100 * np.sqrt(((x-y)**2)).mean()/y.mean()

# %%
spec_list = glob("data/calibrated/20190805/IJV/20190805_*.csv")
spec_list.sort(key=
    lambda x: (int(x.split('_')[-2]), int(x.split('_')[-1].strip('.csv'))) 
)

# %%
geo_max=[2, 2.25, 5.21, 13, 6, 16, 3]
geo_min=[2, 2.25, 3.69, 13, 6, 16, 3]
log_phantom = []

# %%
wl = [i for i in range(660, 811, 10)]
ratio = [1, 0.66, 0.5, 0.33, 0]

# %%
spec_list
# Out:
# ['data/calibrated/20190805/IJV/20190805_1_1.csv',
#  'data/calibrated/20190805/IJV/20190805_1_2.csv',
#  'data/calibrated/20190805/IJV/20190805_1_3.csv',
#  'data/calibrated/20190805/IJV/20190805_1_4.csv',
#  'data/calibrated/20190805/IJV/20190805_1_5.csv',
#  'data/calibrated/20190805/IJV/20190805_2_1.csv',
#  'data/calibrated/20190805/IJV/20190805_2_2.csv',
#  'data/calibrated/20190805/IJV/20190805_2_3.csv',
#  'data/calibrated/20190805/IJV/20190805_2_4.csv',
#  'data/calibrated/20190805/IJV/20190805_2_5.csv',
#  'data/calibrated/20190805/IJV/20190805_3_1.csv',
#  'data/calibrated/20190805/IJV/20190805_3_2.csv',
#  'data/calibrated/20190805/IJV/20190805_3_3.csv',
#  'data/calibrated/20190805/IJV/20190805_3_4.csv',
#  'data/calibrated/20190805/IJV/20190805_3_5.csv',
#  'data/calibrated/20190805/IJV/20190805_4_1.csv',
#  'data/calibrated/20190805/IJV/20190805_4_2.csv',
#  'data/calibrated/20190805/IJV/20190805_4_3.csv',
#  'data/calibrated/20190805/IJV/20190805_4_4.csv',
#  'data/calibrated/20190805/IJV/20190805_4_5.csv',
#  'data/calibrated/20190805/IJV/20190805_5_1.csv',
#  'data/calibrated/20190805/IJV/20190805_5_2.csv',
#  'data/calibrated/20190805/IJV/20190805_5_3.csv',
#  'data/calibrated/20190805/IJV/20190805_5_4.csv',
#  'data/calibrated/20190805/IJV/20190805_5_5.csv']

# %%
for s in spec_list[3:5]:
    print(s)
    idx = "{:d}_{:d}".format(int(s.split('_')[-2]), int(s.split('_')[-1].strip('.csv')))
    print(idx)
    if not os.path.isdir("fitting/phantom2/" + idx):
        os.mkdir("fitting/phantom2/" + idx)
    spec = pd.read_csv(s)
    spec = spec[
        (spec["wavelength"] >= wl[0])&
        (spec["wavelength"] <= wl[-1])
    ]
    target_max = spec["max"].values.T
    target_min = spec["min"].values.T
    
    ga = GA(1000, 24, target_max, target_min, geo_max, geo_min, dual_ratio=0.05, iteration=1000, log_period=10, phantom=True) #, ink_ratio=r)
    ga(plot=True, verbose=True, output_dir="fitting/phantom2/" + idx)
    log_phantom += [deepcopy(ga)]
# Out:
# data/calibrated/20190805/IJV/20190805_1_4.csv
# 1_4
# epoch 0:
# Size of gene library: 1000
# best fit error: 46.197916
# best fit spectrum rmsp: 42.31
# best fit absorption rmsp: 77.76
# ijv scvO2: 0.45
# epoch 10:
# Size of gene library: 1000
# best fit error: 33.608074
# best fit spectrum rmsp: 30.03
# best fit absorption rmsp: 71.64
# ijv scvO2: 0.10
# epoch 20:
# Size of gene library: 1000
# best fit error: 33.608074
# best fit spectrum rmsp: 30.03
# best fit absorption rmsp: 71.64
# ijv scvO2: 0.10
# epoch 30:
# Size of gene library: 1000
# best fit error: 31.069215
# best fit spectrum rmsp: 26.89
# best fit absorption rmsp: 83.63
# ijv scvO2: 1.00
# epoch 40:
# Size of gene library: 1000
# best fit error: 30.265287
# best fit spectrum rmsp: 26.82
# best fit absorption rmsp: 68.83
# ijv scvO2: 0.75
# epoch 50:
# Size of gene library: 1000
# best fit error: 27.997598
# best fit spectrum rmsp: 22.94
# best fit absorption rmsp: 101.24
# ijv scvO2: 0.31
# epoch 60:
# Size of gene library: 1000
# best fit error: 18.842955
# best fit spectrum rmsp: 14.78
# best fit absorption rmsp: 81.22
# ijv scvO2: 0.49
# epoch 70:
# Size of gene library: 1000
# best fit error: 18.842955
# best fit spectrum rmsp: 14.78
# best fit absorption rmsp: 81.22
# ijv scvO2: 0.49
# epoch 80:
# Size of gene library: 1000
# best fit error: 18.842955
# best fit spectrum rmsp: 14.78
# best fit absorption rmsp: 81.22
# ijv scvO2: 0.49
# epoch 90:
# Size of gene library: 1000
# best fit error: 17.792349
# best fit spectrum rmsp: 14.03
# best fit absorption rmsp: 75.23
# ijv scvO2: 0.57
# epoch 100:
# Size of gene library: 1000
# best fit error: 17.792349
# best fit spectrum rmsp: 14.03
# best fit absorption rmsp: 75.23
# ijv scvO2: 0.57
# epoch 110:
# Size of gene library: 1000
# best fit error: 17.161532
# best fit spectrum rmsp: 12.71
# best fit absorption rmsp: 89.10
# ijv scvO2: 0.51
# epoch 120:
# Size of gene library: 1000
# best fit error: 14.415257
# best fit spectrum rmsp: 10.45
# best fit absorption rmsp: 79.32
# ijv scvO2: 0.57
# epoch 130:
# Size of gene library: 1000
# best fit error: 14.415257
# best fit spectrum rmsp: 10.45
# best fit absorption rmsp: 79.32
# ijv scvO2: 0.57
# epoch 140:
# Size of gene library: 1000
# best fit error: 14.133993
# best fit spectrum rmsp: 10.40
# best fit absorption rmsp: 74.74
# ijv scvO2: 0.63
# epoch 150:
# Size of gene library: 1000
# best fit error: 14.133993
# best fit spectrum rmsp: 10.40
# best fit absorption rmsp: 74.74
# ijv scvO2: 0.63
# epoch 160:
# Size of gene library: 1000
# best fit error: 14.105331
# best fit spectrum rmsp: 10.37
# best fit absorption rmsp: 74.71
# ijv scvO2: 0.62
# epoch 170:
# Size of gene library: 1000
# best fit error: 14.002319
# best fit spectrum rmsp: 10.15
# best fit absorption rmsp: 77.11
# ijv scvO2: 0.56
# epoch 180:
# Size of gene library: 1000
# best fit error: 13.798514
# best fit spectrum rmsp: 9.96
# best fit absorption rmsp: 76.77
# ijv scvO2: 0.62
# epoch 190:
# Size of gene library: 1000
# best fit error: 13.761861
# best fit spectrum rmsp: 10.00
# best fit absorption rmsp: 75.25
# ijv scvO2: 0.60
# epoch 200:
# Size of gene library: 1000
# best fit error: 13.653628
# best fit spectrum rmsp: 9.76
# best fit absorption rmsp: 77.90
# ijv scvO2: 0.57
# /home/md703/toast/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# epoch 210:
# Size of gene library: 1000
# best fit error: 13.560211
# best fit spectrum rmsp: 9.82
# best fit absorption rmsp: 74.86
# ijv scvO2: 0.61
# epoch 220:
# Size of gene library: 1000
# best fit error: 13.497009
# best fit spectrum rmsp: 9.70
# best fit absorption rmsp: 75.86
# ijv scvO2: 0.59
# epoch 230:
# Size of gene library: 1000
# best fit error: 13.414370
# best fit spectrum rmsp: 9.62
# best fit absorption rmsp: 75.95
# ijv scvO2: 0.62
# epoch 240:
# Size of gene library: 1000
# best fit error: 13.329758
# best fit spectrum rmsp: 9.53
# best fit absorption rmsp: 75.90
# ijv scvO2: 0.62
# epoch 250:
# Size of gene library: 1000
# best fit error: 13.327439
# best fit spectrum rmsp: 9.54
# best fit absorption rmsp: 75.81
# ijv scvO2: 0.60
# epoch 260:
# Size of gene library: 1000
# best fit error: 13.227491
# best fit spectrum rmsp: 9.48
# best fit absorption rmsp: 75.03
# ijv scvO2: 0.61
# epoch 270:
# Size of gene library: 1000
# best fit error: 13.201191
# best fit spectrum rmsp: 9.40
# best fit absorption rmsp: 75.97
# ijv scvO2: 0.59
# epoch 280:
# Size of gene library: 1000
# best fit error: 13.145948
# best fit spectrum rmsp: 9.36
# best fit absorption rmsp: 75.70
# ijv scvO2: 0.59
# epoch 290:
# Size of gene library: 1000
# best fit error: 13.025441
# best fit spectrum rmsp: 9.24
# best fit absorption rmsp: 75.64
# ijv scvO2: 0.60
# epoch 300:
# Size of gene library: 1000
# best fit error: 13.025441
# best fit spectrum rmsp: 9.24
# best fit absorption rmsp: 75.64
# ijv scvO2: 0.60
# epoch 310:
# Size of gene library: 1000
# best fit error: 12.995502
# best fit spectrum rmsp: 9.19
# best fit absorption rmsp: 76.10
# ijv scvO2: 0.60
# epoch 320:
# Size of gene library: 1000
# best fit error: 12.953181
# best fit spectrum rmsp: 9.16
# best fit absorption rmsp: 75.85
# ijv scvO2: 0.60
# epoch 330:
# Size of gene library: 1000
# best fit error: 12.945451
# best fit spectrum rmsp: 9.14
# best fit absorption rmsp: 76.08
# ijv scvO2: 0.60
# epoch 340:
# Size of gene library: 1000
# best fit error: 12.939442
# best fit spectrum rmsp: 9.12
# best fit absorption rmsp: 76.35
# ijv scvO2: 0.59
# epoch 350:
# Size of gene library: 1000
# best fit error: 12.891510
# best fit spectrum rmsp: 9.09
# best fit absorption rmsp: 75.97
# ijv scvO2: 0.56
# epoch 360:
# Size of gene library: 1000
# best fit error: 12.875604
# best fit spectrum rmsp: 9.06
# best fit absorption rmsp: 76.23
# ijv scvO2: 0.59
# epoch 370:
# Size of gene library: 1000
# best fit error: 12.875604
# best fit spectrum rmsp: 9.06
# best fit absorption rmsp: 76.23
# ijv scvO2: 0.59
# epoch 380:
# Size of gene library: 1000
# best fit error: 12.875604
# best fit spectrum rmsp: 9.06
# best fit absorption rmsp: 76.23
# ijv scvO2: 0.59
# epoch 390:
# Size of gene library: 1000
# best fit error: 12.875604
# best fit spectrum rmsp: 9.06
# best fit absorption rmsp: 76.23
# ijv scvO2: 0.59
# epoch 400:
# Size of gene library: 1000
# best fit error: 12.875604
# best fit spectrum rmsp: 9.06
# best fit absorption rmsp: 76.23
# ijv scvO2: 0.59
# epoch 410:
# Size of gene library: 1000
# best fit error: 12.875121
# best fit spectrum rmsp: 9.06
# best fit absorption rmsp: 76.35
# ijv scvO2: 0.60
# epoch 420:
# Size of gene library: 1000
# best fit error: 12.875121
# best fit spectrum rmsp: 9.06
# best fit absorption rmsp: 76.35
# ijv scvO2: 0.60
# epoch 430:
# Size of gene library: 1000
# best fit error: 12.869861
# best fit spectrum rmsp: 9.05
# best fit absorption rmsp: 76.41
# ijv scvO2: 0.60
# epoch 440:
# Size of gene library: 1000
# best fit error: 12.865257
# best fit spectrum rmsp: 9.05
# best fit absorption rmsp: 76.36
# ijv scvO2: 0.60
# epoch 450:
# Size of gene library: 1000
# best fit error: 12.862195
# best fit spectrum rmsp: 9.03
# best fit absorption rmsp: 76.67
# ijv scvO2: 0.60
# epoch 460:
# Size of gene library: 1000
# best fit error: 12.861124
# best fit spectrum rmsp: 9.03
# best fit absorption rmsp: 76.54
# ijv scvO2: 0.60
# epoch 470:
# Size of gene library: 1000
# best fit error: 12.857922
# best fit spectrum rmsp: 9.02
# best fit absorption rmsp: 76.82
# ijv scvO2: 0.59
# epoch 480:
# Size of gene library: 1000
# best fit error: 12.852249
# best fit spectrum rmsp: 9.02
# best fit absorption rmsp: 76.71
# ijv scvO2: 0.60
# epoch 490:
# Size of gene library: 1000
# best fit error: 12.847629
# best fit spectrum rmsp: 9.02
# best fit absorption rmsp: 76.65
# ijv scvO2: 0.59
# epoch 500:
# Size of gene library: 1000
# best fit error: 12.845059
# best fit spectrum rmsp: 9.01
# best fit absorption rmsp: 76.70
# ijv scvO2: 0.59
# epoch 510:
# Size of gene library: 1000
# best fit error: 12.839648
# best fit spectrum rmsp: 8.99
# best fit absorption rmsp: 76.95
# ijv scvO2: 0.60
# epoch 520:
# Size of gene library: 1000
# best fit error: 12.833601
# best fit spectrum rmsp: 8.99
# best fit absorption rmsp: 76.96
# ijv scvO2: 0.60
# epoch 530:
# Size of gene library: 1000
# best fit error: 12.829191
# best fit spectrum rmsp: 8.99
# best fit absorption rmsp: 76.86
# ijv scvO2: 0.59
# epoch 540:
# Size of gene library: 1000
# best fit error: 12.822252
# best fit spectrum rmsp: 8.97
# best fit absorption rmsp: 76.96
# ijv scvO2: 0.59
# epoch 550:
# Size of gene library: 1000
# best fit error: 12.819885
# best fit spectrum rmsp: 8.97
# best fit absorption rmsp: 77.01
# ijv scvO2: 0.59
