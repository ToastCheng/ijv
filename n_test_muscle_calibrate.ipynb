# %%
import pandas as pd 
import numpy as np 
from glob import glob
import matplotlib.pyplot as plt 

from utils.preprocess import Calibrator

# %matplotlib inline

# %%
# !ls data/processed/20190510/muscle/live
# !ls data/processed/20190510/muscle/phantom
# Out:
# hwfm_1_1.png hwfm_1_3.png live_1_1.png live_1_2.png live_1_3.png
# hwfm_1_2.png live_1_1.csv live_1_2.csv live_1_3.csv
# hwfm_c.png    hwfm_k.png    phantom_e.csv phantom_i.csv phantom_n.csv
# hwfm_e.png    hwfm_n.png    phantom_e.png phantom_i.png phantom_n.png
# hwfm_h.png    phantom_c.csv phantom_h.csv phantom_k.csv
# hwfm_i.png    phantom_c.png phantom_h.png phantom_k.png

# %%
phantom_measure = []
for p in "chik":
    path = "data/processed/20190510/muscle/phantom/phantom_{}.csv".format(p)
    phantom_measure += [pd.read_csv(path).values.T[1:]] # 波長不用取
phantom_measure = np.asarray(phantom_measure)

phantom_measure.shape
# Out:
# (4, 5, 36)

# %%
a = np.random.rand(5, 36)
b = np.random.rand(5, 36)

# %%
phantom_sim = phantom_measure * a + b

# %% [markdown]
# #### 每根SDS要各別fit！！
# 所以有5 * 36 = 180個參數...!!!

# %%
np.asarray([[[1,2,3,4],[10,20,30,40]], [[0, 0, 0, 0], [91, 92, 93, 94]]]).reshape(2, -1)
# Out:
# array([[ 1,  2,  3,  4, 10, 20, 30, 40],
#        [ 0,  0,  0,  0, 91, 92, 93, 94]])

# %%
phantom_measure.reshape(4, -1).shape
# Out:
# (4, 180)

# %%
calib = Calibrator()
A, B, rr = calib.fit(phantom_measure.reshape(4, -1), phantom_sim.reshape(4, -1))
# A, B, rr = calib.fit(phantom_measure, phantom_sim)
# Out:
# leave: -1, r_square: 1.00
# leave: 0, r_square: 1.00
# leave: 1, r_square: 1.00
# leave: 2, r_square: 1.00
# leave: 3, r_square: 1.00
# finally leave: -1

# %%
A.reshape(5, 36)
# Out:
# array([[0.93063329, 0.68076831, 0.81175969, 0.86156818, 0.61532349,
#         0.96533454, 0.75821794, 0.58074405, 0.04053482, 0.80991901,
#         0.25523405, 0.34113824, 0.79017455, 0.31687706, 0.52280792,
#         0.57552403, 0.63434246, 0.76669631, 0.04312548, 0.54243361,
#         0.22864598, 0.47255205, 0.52386564, 0.53137744, 0.17101107,
#         0.23710034, 0.43758155, 0.41700372, 0.61177595, 0.9038323 ,
#         0.90667148, 0.14842888, 0.09325317, 0.33325817, 0.04121223,
#         0.90075955],
#        [0.16720605, 0.50946888, 0.95689283, 0.71699085, 0.62704809,
#         0.04048939, 0.62475303, 0.4838698 , 0.61812542, 0.90751331,
#         0.51367007, 0.35153478, 0.36653668, 0.92325123, 0.60760907,
#         0.64714105, 0.02885997, 0.80533339, 0.52045121, 0.28495275,
#         0.9473118 , 0.47053799, 0.70193128, 0.42208908, 0.16774073,
#         0.34959761, 0.35546162, 0.14742034, 0.544195  , 0.39339574,
#         0.00401973, 0.27716929, 0.04174702, 0.2055106 , 0.90205598,
#         0.84992543],
#        [0.50559791, 0.56167325, 0.31446761, 0.35271803, 0.39431506,
#         0.48761947, 0.39386287, 0.21476405, 0.80530994, 0.93653501,
#         0.87132106, 0.23293722, 0.05114392, 0.95932329, 0.68183877,
#         0.31752131],
#        [0.22322596, 0.8521247 , 0.25455787, 0.70193061, 0.40575217,
#         0.24299929, 0.38610459, 0.48660046, 0.29915751, 0.01524969,
#         0.70366754, 0.08342632, 0.81871011, 0.44532822, 0.16882688,
#         0.61989539, 0.16239715, 0.74038152, 0.12813237, 0.51941911,
#         0.71890743, 0.98085853, 0.26570671, 0.59612629, 0.20246116,
#         0.55886077, 0.56922507, 0.59872642, 0.44631777, 0.63117877,
#         0.33394666, 0.28990763, 0.63684178, 0.97459319, 0.22463112,
#         0.7736402 ],
#        [0.00765405, 0.41473907, 0.65730983, 0.72503426, 0.76014522,
#         0.99536486, 0.07939661, 0.51830377, 0.2529839 , 0.71971353,
#         0.17414807, 0.13202865, 0.0984019 , 0.97143111, 0.7029314 ,
#         0.29025053, 0.56548098, 0.82446965, 0.70111781, 0.6899775 ,
#         0.26288403, 0.27637802, 0.12719113, 0.76582931, 0.24220849,
#         0.87937201, 0.1922192 , 0.60248118, 0.29073243, 0.25966817,
#         0.91704116, 0.8357003 , 0.52764627, 0.00631618, 0.43167056,
#         0.23907882]])

# %% [markdown]
# #### 底下測試區

# %%
test = np.asarray([[[1, 2, 3], [4, 5, 6]],
           [[10, 20, 30], [40, 50, 60]],
           [[100, 200, 300], [400, 500, 600]
           ]])
test
# Out:
# array([[[  1,   2,   3],
#         [  4,   5,   6]],
#
#        [[ 10,  20,  30],
#         [ 40,  50,  60]],
#
#        [[100, 200, 300],
#         [400, 500, 600]]])

# %%
test[:, :, 0].reshape(-1)
# Out:
# array([  1,   4,  10,  40, 100, 400])

# %%
# [波長數, 仿體數xSDS數]
test.transpose((2, 0, 1)).reshape(test.shape[2], -1)
# Out:
# array([[  1,   4,  10,  40, 100, 400],
#        [  2,   5,  20,  50, 200, 500],
#        [  3,   6,  30,  60, 300, 600]])

# %%
df = pd.read_csv("data/processed/20190510/muscle/phantom/phantom_c.csv")
df.iloc[:, 1:].values.T.shape
# Out:
# (5, 36)

# %%
df["0"]
# Out:
# 0      479.615747
# 1     1221.902804
# 2     1508.062648
# 3     1777.987556
# 4     1978.196088
# 5     2379.334161
# 6     2582.056246
# 7     2895.736055
# 8     3177.175659
# 9     3246.679813
# 10    3741.266449
# 11    3901.874918
# 12    4027.717282
# 13    3970.366492
# 14    4318.978956
# 15    4539.179290
# 16    4470.516846
# 17    4163.928351
# 18    4500.705317
# 19    3761.639710
# 20    4181.737372
# 21    4082.357573
# 22    3319.717393
# 23    2987.911282
# 24    3290.369402
# 25    2332.721736
# 26    2200.300649
# 27    1946.586684
# 28    2274.648024
# 29    1477.382578
# 30    1610.704058
# 31    1360.706009
# 32     875.938907
# 33     784.320230
# 34     740.963175
# 35     640.927591
# Name: 0, dtype: float64

# %%
d = df.iloc[:, 1:].values.T
np.asarray([d, d, d]).shape
# Out:
# (3, 5, 36)
