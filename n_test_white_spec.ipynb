# %%
from utils.mch import MCHHandler
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
mch = MCHHandler()
mch.load_config("configs/train.json")

# %%
ijv_args = {
    "skin":{
        "blood_volume_fraction": 0.5,
        "ScvO2": 0.7,
        "water_volume": 0.49,
        "fat_volume": 0,
        "melanin_volume": 0.01,
    },

    "fat":{
        "blood_volume_fraction": 0,
        "ScvO2": 0,
        "water_volume": 0,
        "fat_volume": 1,
        "melanin_volume": 0,
    },

    "muscle":{
        "blood_volume_fraction": 0.05,
        "ScvO2": 0.80,
        "water_volume": 0.75,
        "fat_volume": 0,
        "melanin_volume": 0,
    },
    "ijv":{
        "blood_volume_fraction": 1,
        "ScvO2": 0.80,
        "water_volume": 0,
        "fat_volume": 0,
        "melanin_volume": 0,
    },
    "cca":{
        "blood_volume_fraction": 1,
        "ScvO2": 0.80,
        "water_volume": 0,
        "fat_volume": 0,
        "melanin_volume": 0,
    },

}

muscle_args = {
    "skin":{
        "blood_volume_fraction": 0.5,
        "ScvO2": 0.7,
        "water_volume": 0.49,
        "fat_volume": 0,
        "melanin_volume": 0.01,
    },

    "fat":{
        "blood_volume_fraction": 0,
        "ScvO2": 0,
        "water_volume": 0,
        "fat_volume": 1,
        "melanin_volume": 0,
    },

    "muscle":{
        "blood_volume_fraction": 0.05,
        "ScvO2": 0.80,
        "water_volume": 0.75,
        "fat_volume": 0,
        "melanin_volume": 0,
    },
    
    "ijv":{
        "blood_volume_fraction": 0.05,
        "ScvO2": 0.80,
        "water_volume": 0.75,
        "fat_volume": 0,
        "melanin_volume": 0,
    },
    "cca":{
        "blood_volume_fraction": 0.05,
        "ScvO2": 0.80,
        "water_volume": 0.75,
        "fat_volume": 0,
        "melanin_volume": 0,
    },
}

# %%
s_m, p_m = mch.run_wmc(muscle_args)
s_i, p_i = mch.run_wmc(ijv_args)
# Out:
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_650.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_660.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_670.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_680.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_690.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_700.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_710.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_720.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_730.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_740.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_750.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_760.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_770.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_780.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_790.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_800.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_810.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_820.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_830.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_840.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_850.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_860.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_870.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_880.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_890.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_900.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_910.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_920.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_930.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_650.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_660.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_670.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_680.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_690.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_700.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_710.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_720.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_730.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_740.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_750.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_760.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_770.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_780.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_790.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_800.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_810.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_820.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_830.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_840.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_850.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_860.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_870.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_880.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_890.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_900.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_910.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_920.mch
# output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_930.mch

# %%
for s in s_m[:5]:
    plt.plot(s)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df, _, _ = mch._load_mch("output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_650.mch")
df[df["detector_idx"]==1].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e973dd86eb00> in <module>
# ----> 1 df, _, _ = mch._load_mch("output/rYhe1jCXEd/mcx_output/rYhe1jCXEd_650.mch")
#       2 df[df["detector_idx"]==1].mean()
#
# NameError: name 'mch' is not defined

# %%
for i in range(1, 9):
    print(i)
    print(df[df["detector_idx"]==i].mean()[1:-1])
    plt.plot(df[df["detector_idx"]==i].mean()[1:-1], label=str(i))
plt.legend()
plt.show()
# Out:
# 1
# media_0     1.460451
# media_1     3.325549
# media_2    11.968539
# media_3     3.721563
# media_4     0.910127
# dtype: float64
# 2
# media_0     1.531292
# media_1     3.606175
# media_2    14.680798
# media_3     4.446294
# media_4     1.044581
# dtype: float64
# 3
# media_0     1.568732
# media_1     3.743013
# media_2    16.138951
# media_3     4.789504
# media_4     1.086311
# dtype: float64
# 4
# media_0     1.603720
# media_1     3.857370
# media_2    17.547882
# media_3     5.063069
# media_4     1.155634
# dtype: float64
# 5
# media_0     1.634892
# media_1     3.985239
# media_2    19.474146
# media_3     5.398267
# media_4     1.213716
# dtype: float64
# 6
# media_0     2.158204
# media_1     5.438277
# media_2    44.262659
# media_3    13.576978
# media_4     7.392563
# dtype: float64
# 7
# media_0     2.273243
# media_1     5.732200
# media_2    51.472913
# media_3    14.612936
# media_4     8.927404
# dtype: float64
# 8
# media_0     2.355813
# media_1     5.948199
# media_2    58.297005
# media_3    15.394507
# media_4    10.314396
# dtype: float64

# %%
s.shape
# Out:
# (8, 29)

# %%
for ss in s[:5]:
    plt.plot(ss)

# %%
for ss in s[5:]:
    plt.plot(ss)

# %%
for ss in s:
    plt.plot(ss)

# %%
for pp in p:
    plt.plot(pp)

# %%
mch = MCHHandler()
mch.load_config("configs/config.json")
s, p = mch.run_wmc(ijv_args)

# %%
for ss in s[:5]:
    plt.plot(ss)
plt.show()

for ss in s[5:]:
    plt.plot(ss)
plt.show()

for ss in s:
    plt.plot(ss)
plt.show()

# %%
df, _, _ = mch._load_mch("output/quicktest/mcx_output/quicktest_650.mch")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d59d837e005c> in <module>
# ----> 1 df, _, _ = mch._load_mch()
#
# TypeError: _load_mch() missing 1 required positional argument: 'path'

# %%
wl = [i for i in range(650, 1001, 10)]

mh = MCHHandler()

mh.load_config("configs/muscle.json")

def calculate_mua(b, s, w, f, m, oxy, deoxy, water, fat, melanin):
    mua = b * (s * oxy + (1-s) * deoxy) + w * water + f * fat + m * melanin
    return mua

mua = pd.read_csv("input/coefficients.csv")
oxy = mua['oxy'].values
deoxy = mua['deoxy'].values
water = mua['water'].values
collagen = mua['collagen'].values
fat = mua['fat'].values
melanin = mua['mel'].values
wavelength = mua['wavelength'].values

# interpolation
oxy = np.interp(wl, wavelength, oxy)
deoxy = np.interp(wl, wavelength, deoxy)
water = np.interp(wl, wavelength, water)
collagen = np.interp(wl, wavelength, collagen)
fat = np.interp(wl, wavelength, fat)
melanin = np.interp(wl, wavelength, melanin)

# turn the unit 1/cm --> 1/mm
oxy *= 0.1
deoxy *= 0.1
water *= 0.1
collagen *= 0.1
fat *= 0.1
melanin *= 0.1

# %%
args = {
    "skin":{
        "blood_volume_fraction": 0.5,
        "ScvO2": 0.7,
        "water_volume": 0.49,
        "fat_volume": 0,
        "melanin_volume": 0.01,
    },

    "fat":{
        "blood_volume_fraction": 0,
        "ScvO2": 0,
        "water_volume": 0,
        "fat_volume": 1,
        "melanin_volume": 0,
    },

    "muscle":{
        "blood_volume_fraction": 0.05,
        "ScvO2": 0.80,
        "water_volume": 0.75,
        "fat_volume": 0,
        "melanin_volume": 0,
    }
}

spec, ratio = mh.calculate_reflectance_white(args)
for t in ["skin", "fat", "muscle"][:0]:
    mua = calculate_mua(
        args[t]["blood_volume_fraction"],
        args[t]["ScvO2"],
        args[t]["water_volume"],
        args[t]["fat_volume"],
        args[t]["melanin_volume"],
        oxy, 
        deoxy, 
        water, 
        fat, 
        melanin
    )

plt.plot(wl, mua, label="blood: %f" % i)
plt.xlabel("wavelength [nm]")
plt.ylabel("mua [1/mm]")
plt.grid()
plt.legend()
plt.show()

for i in range(5):
    plt.plot(wl, spec[i], label="%d" % i)
plt.grid()
plt.xlabel("wavelength [nm]")
plt.ylabel("reflectance [-]")
plt.legend()
plt.show()

# %%
spec = []
mua = []
for i in np.arange(0, 1, 0.1):
    args = {
        "skin":{
            "blood_volume_fraction": i,
            "ScvO2": 0.7,
            "water_volume": 1 - i - 0.01,
            "fat_volume": 0,
            "melanin_volume": 0.01,
        },

        "fat":{
            "blood_volume_fraction": 0,
            "ScvO2": 0,
            "water_volume": 0,
            "fat_volume": 1,
            "melanin_volume": 0,
        },

        "muscle":{
            "blood_volume_fraction": 0.05,
            "ScvO2": 0.80,
            "water_volume": 0.75,
            "fat_volume": 0,
            "melanin_volume": 0,
        }
    }

    s, ratio = mh.calculate_reflectance_white(args)
    spec.append(s)
    for t in ["skin", "fat", "muscle"][:1]:
        m = calculate_mua(
            args[t]["blood_volume_fraction"],
            args[t]["ScvO2"],
            args[t]["water_volume"],
            args[t]["fat_volume"],
            args[t]["melanin_volume"],
            oxy, 
            deoxy, 
            water, 
            fat, 
            melanin
        )
        mua.append(m)

# %%
plt.figure(figsize=(10, 8))
for idx, m in enumerate(mua):
    plt.plot(wl, m, label="blood: %.1f" % (idx*0.1))
plt.xlabel("wavelength [nm]")
plt.ylabel("mua [1/mm]")
plt.grid()
plt.legend()
plt.savefig("skin_blood_mua.png")
plt.clf()

plt.figure(figsize=(10, 8))
for idx, s in enumerate(spec):
    for i in range(5):
        if i == 0:
            plt.plot(wl, s[i], color="C%d" % idx, label="blood: %.1f" % (idx*0.1))
        else:
            plt.plot(wl, s[i], color="C%d" % idx)
plt.grid()
plt.title("skin")
plt.xlabel("wavelength [nm]")
plt.ylabel("reflectance [-]")
plt.legend()
plt.savefig("skin_blood_spec.png")
plt.clf()

# %%
spec2 = []
mua2 = []
for i in np.arange(0, 1, 0.1):
    args = {
        "skin":{
            "blood_volume_fraction": 0.5,
            "ScvO2": i,
            "water_volume": 0.49,
            "fat_volume": 0,
            "melanin_volume": 0.01,
        },

        "fat":{
            "blood_volume_fraction": 0,
            "ScvO2": 0,
            "water_volume": 0,
            "fat_volume": 1,
            "melanin_volume": 0,
        },

        "muscle":{
            "blood_volume_fraction": 0.05,
            "ScvO2": 0.80,
            "water_volume": 0.75,
        }
    }

    s, ratio = mh.calculate_reflectance_white(args)
    spec2.append(s)
    for t in ["skin", "fat", "muscle"][:1]:
        m = calculate_mua(
            args[t]["blood_volume_fraction"],
            args[t]["ScvO2"],
            args[t]["water_volume"],
            args[t]["fat_volume"],
            args[t]["melanin_volume"],
            oxy, 
            deoxy, 
            water, 
            fat, 
            melanin
        )
        mua2.append(m)

# %%
plt.figure(figsize=(10, 8))
for idx, m in enumerate(mua2):
    plt.plot(wl, m, label="scv: %.1f" % (idx*0.1))
plt.xlabel("wavelength [nm]")
plt.ylabel("mua [1/mm]")
plt.grid()
plt.legend()
plt.savefig("skin_scv_mua.png")
plt.clf()

plt.figure(figsize=(10, 8))
for idx, s in enumerate(spec2):
    for i in range(5):
        if i == 0:
            plt.plot(wl, s[i], color="C%d" % idx, label="scv: %.1f" % (idx*0.1))
        else:
            plt.plot(wl, s[i], color="C%d" % idx)
plt.grid()
plt.title("skin")
plt.xlabel("wavelength [nm]")
plt.ylabel("reflectance [-]")
plt.legend()
plt.savefig("skin_scv_spec.png")
plt.clf()

# %%
def calculate_mua_muscle(b, s, w, oxy, deoxy, water, collagen):
    mua = w * water + (1-w-b) * collagen + b * (s * oxy + (1-s) * deoxy)

    return mua

# %%
spec3 = []
mua3 = []
for i in np.arange(0.5, 0.8, 0.05):
    args = {
        "skin":{
            "blood_volume_fraction": 0.5,
            "ScvO2": 0.7,
            "water_volume": 0.49,
            "fat_volume": 0,
            "melanin_volume": 0.01,
        },

        "fat":{
            "blood_volume_fraction": 0,
            "ScvO2": 0,
            "water_volume": 0,
            "fat_volume": 1,
            "melanin_volume": 0,
        },

        "muscle":{
            "blood_volume_fraction": 0.05,
            "ScvO2": 0.80,
            "water_volume": i,
            "fat_volume": 0,
            "melanin_volume": 0,
        }
    }

    s, ratio = mh.calculate_reflectance_white(args)
    spec3.append(s)
    for t in ["skin", "fat", "muscle"][-1:]:
        m = calculate_mua_muscle(
            args[t]["blood_volume_fraction"],
            args[t]["ScvO2"],
            args[t]["water_volume"],
            oxy, 
            deoxy, 
            water, 
            collagen
        )
        mua3.append(m)

# %%
plt.figure(figsize=(10, 8))
for idx, m in enumerate(mua3):
    plt.plot(wl, m, label="water: %.1f" % (idx*0.1))
plt.xlabel("wavelength [nm]")
plt.ylabel("mua [1/mm]")
plt.grid()
plt.legend()
plt.savefig("muscle_water_mua.png")
plt.clf()

plt.figure(figsize=(10, 8))
for idx, s in enumerate(spec3):
    for i in range(5):
        if i == 0:
            plt.plot(wl, s[i], color="C%d" % idx, label="water: %.1f" % (idx*0.1))
        else:
            plt.plot(wl, s[i], color="C%d" % idx)
plt.grid()
plt.title("skin")
plt.xlabel("wavelength [nm]")
plt.ylabel("reflectance [-]")
plt.legend()
plt.savefig("muscle_water_spec.png")
plt.clf()
