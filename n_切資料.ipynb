# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
date = "20190528"
i = 2

# %%
d = np.loadtxt("data/raw/{}/IJV/live/live_2_1.csv".format(date), delimiter=',')

# %%
d.shape
# Out:
# (18088, 400)

# %%
plt.plot(d.mean(1))

# %%
d1 = d[:400]
plt.plot(d1.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_1.csv".format(date, i), 
    d1,
    delimiter=","
)

# %%
d2 = d[600:4600]
plt.plot(d2.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_2.csv".format(date, i), 
    d2,
    delimiter=","
)

# %%
d3 = d[10800:11800]
plt.plot(d3.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_3.csv".format(date, i), 
    d3,
    delimiter=","
)
