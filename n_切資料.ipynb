# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
date = "20190528"
i = 5

# %%
d = np.loadtxt("data/raw/{}/IJV/live/live_4_1.csv".format(date), delimiter=',')

# %%
d.shape
# Out:
# (8438, 400)

# %%
plt.plot(d.mean(1))

# %%
d1 = d[300:450]
plt.plot(d1.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_1.csv".format(date, i), 
    d1,
    delimiter=","
)

# %%
d2 = d[2600:3600]
plt.plot(d2.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_2.csv".format(date, i), 
    d2,
    delimiter=","
)

# %%
d3 = d[7850:]
plt.plot(d3.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_3.csv".format(date, i), 
    d3,
    delimiter=","
)

# %%
d4 = d[12000:14400]
plt.plot(d4.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_4.csv".format(date, i), 
    d4,
    delimiter=","
)

# %%
d5 = d[16400:16900]
plt.plot(d5.mean(1))
np.savetxt(
    "data/raw/{}_split/IJV/live/live_{}_5.csv".format(date, i), 
    d5,
    delimiter=","
)
